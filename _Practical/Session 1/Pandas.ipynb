# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/BCI/test.csv')
len(df)
# Out:
# 3307

# %%
df.head(10)
# Out:
#    Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 0           0    KS             128  ...  False         10            0
# 1           1    OH             107  ...  False        100            0
# 2           2    NJ             137  ...  False        100            0
# 3           3    OH              84  ...  False        100            0
# 4           4    OK              75  ...  False        100            0
# 5           5    AL             118  ...  False        100            0
# 6           7    MO             147  ...  False        100            0
# 7           8    LA             117  ...  False        100            0
# 8           9    WV             141  ...  False        100            0
# 9          10    IN              65  ...   True        100            1
#
# [10 rows x 23 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 3302        3328    AZ             192  ...  False        100            0
# 3303        3329    WV              68  ...  False        100            0
# 3304        3330    RI              28  ...  False        100            0
# 3305        3331    CT             184  ...  False        100            0
# 3306        3332    TN              74  ...  False        100            0
#
# [5 rows x 23 columns]

# %%
for each in df.columns:
  print(each)
# Out:
# Unnamed: 0
# State
# Account length
# Area code
# International plan
# Voice mail plan
# Number vmail messages
# Total day minutes
# Total day calls
# Total day charge
# Total eve minutes
# Total eve calls
# Total eve charge
# Total night minutes
# Total night calls
# Total night charge
# Total intl minutes
# Total intl calls
# Total intl charge
# Customer service calls
# Churn
# New Column
# Churn Binary

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                        bool
# New Column                  int64
# Churn Binary                int64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0  Account length  ...   New Column  Churn Binary
# count  3307.000000     3307.000000  ...  3307.000000   3307.000000
# mean   1678.736015      101.072573  ...    99.972785      0.145147
# std     955.240389       39.808520  ...     1.565040      0.352302
# min       0.000000        1.000000  ...    10.000000      0.000000
# 25%     852.500000       74.000000  ...   100.000000      0.000000
# 50%    1679.000000      101.000000  ...   100.000000      0.000000
# 75%    2505.500000      127.000000  ...   100.000000      0.000000
# max    3332.000000      243.000000  ...   100.000000      1.000000
#
# [8 rows x 19 columns]

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan
# count   3307               3307            3307
# unique    51                  2               2
# top       WV                 No              No
# freq     106               2985            2396

# %%
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 0           0    KS             128  ...  False         10            0
# 1           1    OH             107  ...  False        100            0
# 2           2    NJ             137  ...  False        100            0
# 3           3    OH              84  ...  False        100            0
# 4           4    OK              75  ...  False        100            0
#
# [5 rows x 23 columns]

# %%
df.Churn
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3302    False
# 3303    False
# 3304    False
# 3305    False
# 3306    False
# Name: Churn, Length: 3307, dtype: bool

# %%
df['Account length']
# Out:
# 0       128
# 1       107
# 2       137
# 3        84
# 4        75
#        ...
# 3302    192
# 3303     68
# 3304     28
# 3305    184
# 3306     74
# Name: Account length, Length: 3307, dtype: int64

# %%
df[['Account length', 'Voice mail plan']]
# Out:
#       Account length Voice mail plan
# 0                128             Yes
# 1                107             Yes
# 2                137              No
# 3                 84              No
# 4                 75              No
# ...              ...             ...
# 3302             192             Yes
# 3303              68              No
# 3304              28              No
# 3305             184              No
# 3306              74             Yes
#
# [3307 rows x 2 columns]

# %%
df.Churn.unique()
# Out:
# array([False,  True])

# %%
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 0           0    KS             128  ...  False         10            0
# 1           1    OH             107  ...  False        100            0
# 2           2    NJ             137  ...  False        100            0
# 3           3    OH              84  ...  False        100            0
# 4           4    OK              75  ...  False        100            0
#
# [5 rows x 23 columns]

# %%
df[df['State'] == 'NJ']
# Out:
#       Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 2              2    NJ             137  ...  False        100            0
# 18            39    NJ             149  ...  False        100            0
# 49            70    NJ             138  ...  False        100            0
# 68            89    NJ             128  ...   True        100            1
# 95           116    NJ              64  ...  False        100            0
# ...          ...   ...             ...  ...    ...        ...          ...
# 3008        3034    NJ              75  ...  False        100            0
# 3100        3126    NJ             108  ...  False        100            0
# 3110        3136    NJ             107  ...  False        100            0
# 3222        3248    NJ              93  ...  False        100            0
# 3253        3279    NJ             139  ...  False        100            0
#
# [68 rows x 23 columns]

# %%
df[df['Area code'] > 415]
# Out:
#       Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 5              5    AL             118  ...  False        100            0
# 12            24    VA             132  ...  False        100            0
# 21            42    AR              34  ...  False        100            0
# 23            44    WI              64  ...  False        100            0
# 41            62    MN              74  ...  False        100            0
# ...          ...   ...             ...  ...    ...        ...          ...
# 3278        3304    IL              71  ...   True        100            1
# 3290        3316    MS             103  ...  False        100            0
# 3294        3320    GA             122  ...   True        100            1
# 3304        3330    RI              28  ...  False        100            0
# 3305        3331    CT             184  ...  False        100            0
#
# [832 rows x 23 columns]

# %%
df[df['Area code'] > 414]['Area code'].unique()
# Out:
# array([415, 510])

# %%
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 0           0    KS             128  ...  False         10            0
# 1           1    OH             107  ...  False        100            0
# 2           2    NJ             137  ...  False        100            0
# 3           3    OH              84  ...  False        100            0
# 4           4    OK              75  ...  False        100            0
#
# [5 rows x 23 columns]

# %%
df_state = df.copy()
df_state.set_index('State', inplace=True)
df_state.head()
# Out:
#        Unnamed: 0  Account length  Area code  ...  Churn New Column  Churn Binary
# State                                         ...
# KS              0             128        415  ...  False         10             0
# OH              1             107        415  ...  False        100             0
# NJ              2             137        415  ...  False        100             0
# OH              3              84        408  ...  False        100             0
# OK              4              75        415  ...  False        100             0
#
# [5 rows x 22 columns]

# %%
import numpy as np
df['InsertNA'] = np.nan
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  New Column Churn Binary InsertNA
# 0           0    KS             128  ...          10            0      NaN
# 1           1    OH             107  ...         100            0      NaN
# 2           2    NJ             137  ...         100            0      NaN
# 3           3    OH              84  ...         100            0      NaN
# 4           4    OK              75  ...         100            0      NaN
#
# [5 rows x 24 columns]

# %%
df.InsertNA[3:] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  New Column Churn Binary InsertNA
# 0           0    KS             128  ...          10            0      NaN
# 1           1    OH             107  ...         100            0      NaN
# 2           2    NJ             137  ...         100            0      NaN
# 3           3    OH              84  ...         100            0      1.0
# 4           4    OK              75  ...         100            0      1.0
#
# [5 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# New Column                0
# Churn Binary              0
# InsertNA                  3
# dtype: int64

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  New Column Churn Binary InsertNA
# 3           3    OH              84  ...         100            0      1.0
# 4           4    OK              75  ...         100            0      1.0
# 5           5    AL             118  ...         100            0      1.0
# 6           7    MO             147  ...         100            0      1.0
# 7           8    LA             117  ...         100            0      1.0
#
# [5 rows x 24 columns]

# %%
df.drop('InsertNA', axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0 State  Account length  ...  Churn New Column Churn Binary
# 3           3    OH              84  ...  False        100            0
# 4           4    OK              75  ...  False        100            0
# 5           5    AL             118  ...  False        100            0
# 6           7    MO             147  ...  False        100            0
# 7           8    LA             117  ...  False        100            0
#
# [5 rows x 23 columns]

# %%
df['Binary'] = df['Churn'].apply(lambda x: 1 if x == True else 0)
df.head()
# Out:
#     Unnamed: 0 State  Account length  ...  New Column Churn Binary Binary
# 3            3    OH              84  ...         100            0      0
# 4            4    OK              75  ...         100            0      0
# 5            5    AL             118  ...         100            0      0
# 6            7    MO             147  ...         100            0      0
# 7            8    LA             117  ...         100            0      0
# 8            9    WV             141  ...         100            0      0
# 9           10    IN              65  ...         100            1      1
# 10          11    RI              74  ...         100            0      0
# 11          23    SC             111  ...         100            0      0
# 12          24    VA             132  ...         100            0      0
#
# [10 rows x 24 columns]

# %%
df[df['Churn'] == True].head()
# Out:
#     Unnamed: 0 State  Account length  ...  New Column Churn Binary Binary
# 9           10    IN              65  ...         100            1      1
# 20          41    MD             135  ...         100            1      1
# 27          48    ID             119  ...         100            1      1
# 33          54    WY              87  ...         100            1      1
# 36          57    CO             121  ...         100            1      1
#
# [5 rows x 24 columns]

# %%
df.to_csv('output.csv')
