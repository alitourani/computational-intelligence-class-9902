# %%
import numpy as np

# %%
a = [1, 2, 3.2, 'hello', [[['a', 3]]]]
a
# Out:
# [1, 2, 3.2, 'hello', [[['a', 3]]]]

# %%
a = np.array([1, 1, 1], dtype='int32')
a
# Out:
# array([1, 1, 1], dtype=int32)

# %%
b = np.array([
              [1, 1, 1, 1],
              [2, 2, 2, 2]
])

# %%
a.dtype
# Out:
# dtype('int32')

# %%
c = np.array([
              [1, 2, 3, 4, 10],
              [5, 6, 7, 8, 11]
])
c
# Out:
# array([[ 1,  2,  3,  4, 10],
#        [ 5,  6,  7,  8, 11]])

# %%
c[1, 2]
# Out:
# 7

# %%
c[0, :]
# Out:
# array([ 1,  2,  3,  4, 10])

# %%
c[:, 0]
# Out:
# array([1, 5])

# %%
c[:, :]
# Out:
# array([[ 1,  2,  3,  4, 10],
#        [ 5,  6,  7,  8, 11]])

# %%
c[1, 0::2]
# Out:
# array([ 5,  7, 11])

# %%
c[0, 0] = 20
c
# Out:
# array([[20,  2,  3,  4, 10],
#        [ 5,  6,  7,  8, 11]])

# %%
c[0] = [1, 2, 3, 4, 5]

# %%
ones_array = np.ones([2, 2], dtype='int32')
zeros_array = np.zeros([2, 2], dtype='int32')
print(zeros_array)
print()
print(ones_array)
# Out:
# [[0 0]
#  [0 0]]
#
# [[1 1]
#  [1 1]]

# %%
full_array = np.full([2, 2], 23)
full_array
# Out:
# array([[23, 23],
#        [23, 23]])

# %%
full_array = np.full_like(c, 23)
full_array
# Out:
# array([[23, 23, 23, 23, 23],
#        [23, 23, 23, 23, 23]])

# %%
rnd_array = np.random.rand(c.shape[0], c.shape[1])
rnd_array
# Out:
# array([[0.22288119, 0.31363616, 0.75219641, 0.11537217, 0.46113258],
#        [0.68752023, 0.35635707, 0.75695123, 0.86672163, 0.51611031]])

# %%
rnd_array = np.random.randint(10, 15, size=c.shape)
rnd_array
# Out:
# array([[13, 12, 13, 11, 10],
#        [12, 10, 14, 14, 13]])

# %%
d = c.copy()
d[0, 0] = 200
d
# Out:
# array([[200,  20,  20,  20,  20],
#        [  5,   6,   7,   8,  11]])

# %%
c
# Out:
# array([[20, 20, 20, 20, 20],
#        [ 5,  6,  7,  8, 11]])

# %%
tmp = (ones_array + 3) ** 2
tmp = np.sin(tmp)
tmp
# Out:
# array([[-0.28790332, -0.28790332],
#        [-0.28790332, -0.28790332]])

# %%
a = np.ones([2, 4])
b = np.full([4, 3], 4)
print(a)
print(b)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]
# [[4 4 4]
#  [4 4 4]
#  [4 4 4]
#  [4 4 4]]

# %%
np.matmul(a, b)
# Out:
# array([[16., 16., 16.],
#        [16., 16., 16.]])

# %%
idy = np.identity(5)

# %%
np.linalg.det(idy)
# Out:
# 1.0

# %%
c
# Out:
# array([[20, 20, 20, 20, 20],
#        [ 5,  6,  7,  8, 11]])

# %%
np.min(c, axis=1)
# Out:
# array([20,  5])

# %%
c.reshape([5, 2])
# Out:
# array([[20, 20],
#        [20, 20],
#        [20,  5],
#        [ 6,  7],
#        [ 8, 11]])
